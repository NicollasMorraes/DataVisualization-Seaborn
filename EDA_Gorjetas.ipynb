# %% [markdown]
# <a href="https://colab.research.google.com/github/NicollasMorraes/Java-Consumindo-WebService/blob/main/EDA_Gorjetas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando base de dados

# %%
import pandas as pd

# %%
pd.read_csv('tips.csv')
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados = pd.read_csv('tips.csv')

# %%
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %% [markdown]
# # Traduzindo Informações

# %%
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill': 'valor_da_conta', 'tip' : 'gorjeta', 'dessert': 'sobremesa', 'day' : 'dia_da_semana', 'time' : 'hora_do_dia', 'size' : 'total_de_pessoas'
}

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No': 'Não',
    'Yes': 'Sim'
}

# %%
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
   'Sun': 'Domingo', 'Sat': 'Sábado', 'Thur': 'Quinta', 'Fri' : 'Sexta'
}

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
gorjetas.head(5)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
# 1           10.34     1.66       Não       Domingo      Dinner
# 2           21.01     3.50       Não       Domingo      Dinner
# 3           23.68     3.31       Não       Domingo      Dinner
# 4           24.59     3.61       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner' : 'Janta', 'Lunch' : 'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas.head(5)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo       Janta
# 1           10.34     1.66       Não       Domingo       Janta
# 2           21.01     3.50       Não       Domingo       Janta
# 3           23.68     3.31       Não       Domingo       Janta
# 4           24.59     3.61       Não       Domingo       Janta
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %% [markdown]
# # Importandando o Seaborn

# %%
# !pip install seaborn==0.9.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.9.0
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, pandas, scipy
# Required-by: missingno

# %% [markdown]
# # Análise 1 - Valor da conta e gorjeta

# %%
gorjetas.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
valor_gorjeta = sns.scatterplot(x='valor_da_conta', y='gorjeta', data=gorjetas)

# %% [markdown]
# **Visualmente, o valor da gorjeta aumenta conforme aumenta o valor da conta**

# %%
print('A base de dados contém {} de registros \n'.format(gorjetas.shape[0]))
print('Registros não nulos')
gorjetas.count()
# Out:
# A base de dados contém 244 de registros
#
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## Criando o campo porcentagem

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo       Janta
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta']
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo       Janta
# 1           10.34     1.66       Não       Domingo       Janta
# 2           21.01     3.50       Não       Domingo       Janta
# 3           23.68     3.31       Não       Domingo       Janta
# 4           24.59     3.61       Não       Domingo       Janta
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas.head(3)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo       Janta
# 1           10.34     1.66       Não       Domingo       Janta
# 2           21.01     3.50       Não       Domingo       Janta
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# **Visualmente, o valor da conta não é proporcional ao valor da gorjeta**

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', kind='line', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# # Análise 2 - Sobremesa

# %%
gorjetas[gorjetas.sobremesa =='Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa =='Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', kind='line', data=gorjetas)

# %% [markdown]
# **Visualmente, existe uma diferença no valor da gorjeta daqueles que pediram sobremesa e não pediram**

# %% [markdown]
# # Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
#
# >**A distribuição da taxa da gorjeta é a mesma nos dois grupos**
#
# **H<sup>alt</sup>**
# >**A distribuição da taxa da gorjeta não é a mesma nos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# **H<sup>null</sup>**
#
# >**A distribuição da taxa da gorjeta é a mesma nos dois grupos**

# %% [markdown]
# # Análise 3 - Dia de Semana

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo       Janta
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x='dia_da_semana', y='valor_da_conta', hue='dia_da_semana' ,data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana' ,data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana' ,data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()

# %%
print('A média geral das gorjetas {} é de'.format(media_geral_gorjetas))
# Out:
# A média geral das gorjetas 2.99827868852459 é de

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
# <ipython-input-130-a13207cc9443>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# ***H<sup>null</sup>**
# >**A distribuição do valor da conta é igual no sábado e no domingo**
#
# **H<sup>alt</sup>**
# >**A distribuição do valor da conta não é igual no sábado e no domingo**

# %%
conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
conta_quinta = gorjetas.query("dia_da_semana == 'Quinta'").valor_da_conta

# %%
conta_sexta = gorjetas.query("dia_da_semana == 'Sexta'").valor_da_conta

# %%
r2=ranksums(conta_domingo, conta_sabado)

# %% [markdown]
# ***H<sup>null</sup>**
# >**A distribuição do valor da conta é igual no sábado e no domingo**

# %%
print('O valor do p-value é {}'.format(r2.pvalue))
# Out:
# O valor do p-value é 0.3576728477868443

# %% [markdown]
# #Análise 4 - Hora do dia

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Janta', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', hue='hora_do_dia',data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', kind='swarm',hue='hora_do_dia',data=gorjetas)

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta',hue='hora_do_dia', data=gorjetas)
# Out:
# <Axes: xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <Axes: xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.distplot(almoco)
# Out:
# <ipython-input-162-92c0566e5cfe>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(almoco)
# <Axes: xlabel='valor_da_conta', ylabel='Density'>

# %%
sns.distplot(almoco, kde=False)
# Out:
# <ipython-input-157-455979eda97e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(almoco, kde=False)
# <Axes: xlabel='valor_da_conta'>

# %%
jantar = gorjetas.query("hora_do_dia == 'Janta'").valor_da_conta

# %%
sns.distplot(jantar)
# Out:
# <ipython-input-164-367de2d91156>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(jantar)
# <Axes: xlabel='valor_da_conta', ylabel='Density'>

# %%
sns.distplot(jantar, kde=False)
# Out:
# <ipython-input-165-273362763c6e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(jantar, kde=False)
# <Axes: xlabel='valor_da_conta'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
# <ipython-input-168-f114a0c0b279>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Janta             20.797159  3.102670     0.159773

# %% [markdown]
# # Teste de Hipótese

# %% [markdown]
# ***H<sup>null</sup>**
# >**A distribuição do valor da conta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
# >**A distribuição do valor da conta não é igual no jantar e no almoço**

# %%
r2 = ranksums(jantar, almoco)

# %%
print('O valor do p-value {}'.format(r.pvalue))
# Out:
# O valor do p-value 0.5266635660124415

# %% [markdown]
# **H<sup>alt</sup>**
# >**A distribuição do valor da conta não é igual no jantar e no almoço**

# %% [markdown]
# ***H<sup>null</sup>**
# >**A distribuição da taxa da gorjeta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
# >**A distribuição da taxa da gorjeta não é igual no jantar e no almoço**

# %%
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Janta'").porcentagem

# %%
 r3 = ranksums(porcentagem_almoco, porcentagem_jantar)

# %%
print('O valor do pvalue é de {}'.format(r3.pvalue))
# Out:
# O valor do pvalue é de 0.2602493995587126

# %% [markdown]
# ***H<sup>null</sup>**
# >**A distribuição da taxa da gorjeta é igual no jantar e no almoço**
